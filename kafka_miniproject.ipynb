# %%
from google.colab import drive
drive.mount('/content/my-drive')
import os
os.chdir('/content/my-drive/My Drive/Colab Notebooks/miniproject')
# Out:
# Drive already mounted at /content/my-drive; to attempt to forcibly remount, call drive.mount("/content/my-drive", force_remount=True).

# %%
#!wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
#!unzip ngrok-stable-linux-amd64.zip
LOG_DIR = './log'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://f78d4d82.ngrok.io

# %%
import tensorflow as tf
from network import execute_model
import my_txtutils as txt
tf.set_random_seed(0)

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
#files = [f for f in os.listdir('.') if os.path.isfile(f)]
#for f in files:
#  print(f)
# Out:
# Found GPU at: /device:GPU:0

# %%
SEQLEN = 60
BATCHSIZE = 200
ALPHASIZE = txt.ALPHASIZE
INTERNALSIZE = 512
NLAYERS = 3
learning_rate = 0.001  # fixed learning rate
dropout_pkeep = 0.8    # some dropout
NO_OF_EPOCHS = 50
# load data, either shakespeare, or the Python source of Tensorflow itself
datadir = "data/kafka/*.txt"
#datadir = "../tensorflow/**/*.py"
codetext, valitext, bookranges = txt.read_data_files(datadir, validation=True);

# display some stats on the data
epoch_size = len(codetext) // (BATCHSIZE * SEQLEN)
txt.print_data_stats(len(codetext), len(valitext), epoch_size)
# Out:
# Training text size is 0.35MB with 63.87KB set aside for validation. There will be 30 batches per epoch

# %%
from tensorflow.contrib import layers
from tensorflow.contrib import rnn  # rnn stuff temporarily in contrib, moving back to code in TF 1.1
import os
import time
import math
import numpy as np

# execute model

#
# the model (see FAQ in README.md)
#
tf.reset_default_graph()
lr = tf.placeholder(tf.float32, name='lr')  # learning rate
pkeep = tf.placeholder(tf.float32, name='pkeep')  # dropout parameter
batchsize = tf.placeholder(tf.int32, name='batchsize')

# inputs
X = tf.placeholder(tf.uint8, [None, None], name='X')    # [ BATCHSIZE, SEQLEN ]
Xo = tf.one_hot(X, ALPHASIZE, 1.0, 0.0)                 # [ BATCHSIZE, SEQLEN, ALPHASIZE ]
# expected outputs = same sequence shifted by 1 since we are trying to predict the next character
Y_ = tf.placeholder(tf.uint8, [None, None], name='Y_')  # [ BATCHSIZE, SEQLEN ]
Yo_ = tf.one_hot(Y_, ALPHASIZE, 1.0, 0.0)               # [ BATCHSIZE, SEQLEN, ALPHASIZE ]
# input state
Hin = tf.placeholder(tf.float32, [None, INTERNALSIZE*NLAYERS], name='Hin')  # [ BATCHSIZE, INTERNALSIZE * NLAYERS]

# using a NLAYERS=3 layers of GRU cells, unrolled SEQLEN=30 times
# dynamic_rnn infers SEQLEN from the size of the inputs Xo

# How to properly apply dropout in RNNs: see README.md
cells = [rnn.GRUCell(INTERNALSIZE) for _ in range(NLAYERS)]
# "naive dropout" implementation
dropcells = [rnn.DropoutWrapper(cell,input_keep_prob=pkeep) for cell in cells]
multicell = rnn.MultiRNNCell(dropcells, state_is_tuple=False)
multicell = rnn.DropoutWrapper(multicell, output_keep_prob=pkeep)  # dropout for the softmax layer

Yr, H = tf.nn.dynamic_rnn(multicell, Xo, dtype=tf.float32, initial_state=Hin)
# Yr: [ BATCHSIZE, SEQLEN, INTERNALSIZE ]
# H:  [ BATCHSIZE, INTERNALSIZE*NLAYERS ] # this is the last state in the sequence

H = tf.identity(H, name='H')  # just to give it a name

# Softmax layer implementation:
# Flatten the first two dimension of the output [ BATCHSIZE, SEQLEN, ALPHASIZE ] => [ BATCHSIZE x SEQLEN, ALPHASIZE ]
# then apply softmax readout layer. This way, the weights and biases are shared across unrolled time steps.
# From the readout point of view, a value coming from a sequence time step or a minibatch item is the same thing.

Yflat = tf.reshape(Yr, [-1, INTERNALSIZE])    # [ BATCHSIZE x SEQLEN, INTERNALSIZE ]
Ylogits = layers.linear(Yflat, ALPHASIZE)     # [ BATCHSIZE x SEQLEN, ALPHASIZE ]
Yflat_ = tf.reshape(Yo_, [-1, ALPHASIZE])     # [ BATCHSIZE x SEQLEN, ALPHASIZE ]
loss = tf.nn.softmax_cross_entropy_with_logits(logits=Ylogits, labels=Yflat_)  # [ BATCHSIZE x SEQLEN ]
loss = tf.reshape(loss, [batchsize, -1])      # [ BATCHSIZE, SEQLEN ]
Yo = tf.nn.softmax(Ylogits, name='Yo')        # [ BATCHSIZE x SEQLEN, ALPHASIZE ]
Y = tf.argmax(Yo, 1)                          # [ BATCHSIZE x SEQLEN ]
Y = tf.reshape(Y, [batchsize, -1], name="Y")  # [ BATCHSIZE, SEQLEN ]
train_step = tf.train.AdamOptimizer(lr).minimize(loss)

# stats for display
seqloss = tf.reduce_mean(loss, 1)
batchloss = tf.reduce_mean(seqloss)
accuracy = tf.reduce_mean(tf.cast(tf.equal(Y_, tf.cast(Y, tf.uint8)), tf.float32))
loss_summary = tf.summary.scalar("batch_loss", batchloss)
acc_summary = tf.summary.scalar("batch_accuracy", accuracy)
summaries = tf.summary.merge([loss_summary, acc_summary])

# Init Tensorboard stuff. This will save Tensorboard information into a different
# folder at each run named 'log/<timestamp>/'. Two sets of data are saved so that
# you can compare training and validation curves visually in Tensorboard.
timestamp = str(math.trunc(time.time()))
summary_writer = tf.summary.FileWriter("log/" + timestamp + "-training")
validation_writer = tf.summary.FileWriter("log/" + timestamp + "-validation")

# Init for saving models. They will be saved into a directory named 'checkpoints'.
# Only the last checkpoint is kept.
if not os.path.exists("checkpoints"):
    os.mkdir("checkpoints")
saver = tf.train.Saver(max_to_keep=1000)

# for display: init the progress bar
DISPLAY_FREQ = 50
_50_BATCHES = DISPLAY_FREQ * BATCHSIZE * SEQLEN
progress = txt.Progress(DISPLAY_FREQ, size=111+2, msg="Training on next "+str(DISPLAY_FREQ)+" batches")

# init
istate = np.zeros([BATCHSIZE, INTERNALSIZE*NLAYERS])  # initial zero input state
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
step = 0

# training loop
for x, y_, epoch in txt.rnn_minibatch_sequencer(codetext, BATCHSIZE, SEQLEN, nb_epochs=NO_OF_EPOCHS):

    # train on one minibatch
    feed_dict = {X: x, Y_: y_, Hin: istate, lr: learning_rate, pkeep: dropout_pkeep, batchsize: BATCHSIZE}
    _, y, ostate = sess.run([train_step, Y, H], feed_dict=feed_dict)

    # log training data for Tensorboard display a mini-batch of sequences (every 50 batches)
    if step % _50_BATCHES == 0:
        feed_dict = {X: x, Y_: y_, Hin: istate, pkeep: 1.0, batchsize: BATCHSIZE}  # no dropout for validation
        y, l, bl, acc, smm = sess.run([Y, seqloss, batchloss, accuracy, summaries], feed_dict=feed_dict)
        #txt.print_learning_learned_comparison(x, y, l, bookranges, bl, acc, epoch_size, step, epoch)
        summary_writer.add_summary(smm, step)

    # run a validation step every 50 batches
    # The validation text should be a single sequence but that's too slow (1s per 1024 chars!),
    # so we cut it up and batch the pieces (slightly inaccurate)
    # tested: validating with 5K sequences instead of 1K is only slightly more accurate, but a lot slower.
    if step % _50_BATCHES == 0 and len(valitext) > 0:
        VALI_SEQLEN = 1*1024  # Sequence length for validation. State will be wrong at the start of each sequence.
        bsize = len(valitext) // VALI_SEQLEN
        txt.print_validation_header(len(codetext), bookranges)
        vali_x, vali_y, _ = next(txt.rnn_minibatch_sequencer(valitext, bsize, VALI_SEQLEN, 1))  # all data in 1 batch
        vali_nullstate = np.zeros([bsize, INTERNALSIZE*NLAYERS])
        feed_dict = {X: vali_x, Y_: vali_y, Hin: vali_nullstate, pkeep: 1.0,  # no dropout for validation
                     batchsize: bsize}
        ls, acc, smm = sess.run([batchloss, accuracy, summaries], feed_dict=feed_dict)
        txt.print_validation_stats(ls, acc)
        # save validation data for Tensorboard
        validation_writer.add_summary(smm, step)

    # display a short text generated with the current weights and biases (every 150 batches)
    if step // 3 % _50_BATCHES == 0:
        txt.print_text_generation_header()
        ry = np.array([[txt.convert_from_alphabet(ord("K"))]])
        rh = np.zeros([1, INTERNALSIZE * NLAYERS])
        for k in range(1000):
            ryo, rh = sess.run([Yo, H], feed_dict={X: ry, pkeep: 1.0, Hin: rh, batchsize: 1})
            rc = txt.sample_from_probabilities(ryo, topn=10 if epoch <= 1 else 2)
            print(chr(txt.convert_to_alphabet(rc)), end="")
            ry = np.array([[rc]])
        txt.print_text_generation_footer()

    # save a checkpoint (every 500 batches)
    if step // 10 % _50_BATCHES == 0:
        saved_file = saver.save(sess, 'checkpoints/rnn_train_' + timestamp, global_step=step)
        print("Saved file: " + saved_file)

    # display progress bar
    progress.step(reset=step % _50_BATCHES == 0)

    # loop state around
    istate = ostate
    step += BATCHSIZE * SEQLEN

sess.close()
# Out:
# Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 4.39432,       accuracy: 0.14892
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
#  rsgi ieleShlkseetni sartetlesihiehailaJi Jnieslm n ihien eeinsm esieinihseeseuleash lren hnhenlsaenlhal  liehrsnnllan hhhlmsnilaelrllaahih nnhmn$ni hmen$lnhrlhsirasnlineaerll ni rlanie ln sseiirr hs sarJel hrmimminmnsasinrahasi;eli sllhhnlhliimli  lihssaiinnn  isJmhir$Jsrhrs siJsms rh;rmnliulsnnhiel seslhs issruaeaulsnnnhmlinhi snr rmueeiisla een nnssiimemrheisneheanrnehenns h ullesrrnsm lalnelhmneiilelneehrehenlh mamsesisnmhe  ;all  am m nailaneilmnanehii nmmsleans erhnea ni a slnah hrmnnsesl;ln  nehhnl mei sl rei nm mralnnl amsmhase;arhsallasadla iai;h   n hrrnmhnmmh$n mrn;m ehmnisihherneaehhaenheaihuh   su slsialliseileiehmnh msmrnhrai a rh nhrsseu lurlhldnmsnes  e lsl rreer eiiastmieahssin lar nmremneu ieiiaru hileiahs rrrinsllneme hiaen n eeniinsieshhnnlehiessiilreeseh sees  srinnhrissnlJrnehrrllnl ssieernlanmsalm iehsrln lamelaiali;lmrenimiia innrnnhssnsshnslu;eeuer eiineuulunnenrie asuuuarehilhlih hrl ieen shisrrll  aeinrmrmliii aeaeeei  uheunnies  ah  renihsniehna nnrmilsirrmm
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
# Saved file: checkpoints/rnn_train_1548283113-0
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 3.08068,       accuracy: 0.16746
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 2.71696,       accuracy: 0.25406
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 2.17040,       accuracy: 0.36948
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
# alllies dich die Tueg sieh ich die Ter den
# Schen sich sie sccht den Schen sich sie den Sckein den Schtand die Sichten der sich die Tuesten sich sch ause sie er waesen die Scheinen die Schaene der Schen den Seie sich seich den
# Wonden den der Schaesten sich der Scheinen den Schaes ind der
# Feren er die Tuest der sch ause die
# Scchend schte die sie eine der Seher die sie den Schte sich die Sehen einen die Seie die Turden der sichten sieher die Schen din dichte seinen der Seinen sicht dis Schen den der sichte ser an den die
# Seinen die Teicht die Seie der Schen der
# Scheinen, win er sehen den sicht an sieh icht aunerer an ert den Schein sie der Sein der sich dich der Schte der Seie sicht and den Seinen die Tur die Schweinen die Schen er die Schen der Seien sie die Schweisen der Seine seinen der Schen der Scht an den Schen die Schan er der Schen der Schte die Schwarte se der sicht die Scheite der Sein den die Schen der Scheit der Scheite die Tues der
# Schanden dich der sich die Scchein der Seine
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.97403,       accuracy: 0.42065
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.83649,       accuracy: 0.45638
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.74692,       accuracy: 0.47788
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
# olfltt, die Schwester die Mand auf dem Beten zu den Kopfen und
# den Schwester so der Verzuten und die Schwaster auf dem
# Konden. Der Verueter als eine Augen der
# Schwesser aus den
# Schlesste sein Gesacht auf dem Frusser uns der Stehe zu dennen Ausseren den Schlassen auf den Fassen, der Schwaster sie sich an den
# Schwaerte die Schwassen die Treisen zierer den Kaenden auf diesem Freine der Stalt zu diesen Sohner,
# abse der Vater all seine Schwester die Schlassen zu dass die Steisen und die Schwesten seit all sich auf dem Bette an den Schwerten den Kanden und dann den Konner auf die Schweser auf dem Steisten war den Schwassen, den Schwester sich auf
# dem Fesser und der Verzueren und dan waren and die Tuse an diesen Soldat an eit alles auf dem Freuste sehen, den Schlessen waere er sich die Schwester den Konner aus den Schwesser die Schwester den Kanz zu schlaechen war er die Tuer
# alseren Sollte die Tuer als einen Schwessen und
# den Kaefen und dan Sie seine Erster und das Gescheitten Sie
# michter au
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.67878,       accuracy: 0.49501
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.62466,       accuracy: 0.50983
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.58257,       accuracy: 0.52021
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
# aung.
#
#
#
# Der Vater sein Geschaefte in der Tuer der Verurteilten, so dann
# er sich auf dem Bett aus dem Besten
# aus dieser
# Freunden des Kanaes auf, die Schwester, die eige sich an die Tuer und die
# Schwester angebeisen, dass er sie auch den Schwester aus den Schwester an der
# Stimme an der Tuer und seine Schwesen und der Schwester auf
# dem Bauer zur Teilen der Troppen auf den Baden, alle Sie
# sich auf dem Bett an der Tuer und die Tuer der Stall aus dem Stuecken
# der Verurteilt war, und die Schwester aus dem Besten aus und den
# Schwester an die Schwester zur Tuer den Kanaper an den Kommandanten auf und die Tuer und
# die Schwester der Vater zur Testen seine Stimme ueder der Vater zu breiben, dass der Verurteilte sie die
# Einen den Stulzen auf den Stulze des Kanden, so sehr auf die Tuere an den Kopf den
# Stimme und die Schwester aus den Schwasen und die Tuer der
# Vater zu sehen, dass es sie alles auf dem Bestell ueber die Stuecken an
# der Tuer ueber seiner Schwester zur Schwerter den
# Kopf auf dem Bete
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.56507,       accuracy: 0.52519
# Saved file: checkpoints/rnn_train_1548283113-6000000
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.52949,       accuracy: 0.53356
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.50922,       accuracy: 0.54191
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
# orpfen, dass er sich auf
# die Schwester den Kopf an den Tuer und der Vater schliesslich an den Schleiben des Vaters der Verurteilte die
# Egge aus dem Fussspaeten schliessen, der erste seines Schwester
# schon so gehen uns in den Steil nicht aus dem Staelken der
# Vater, denn er die Schwester ausgestellt hatte, um den Schwester auf dem Bett,
# alle die Schwester aus dem Bett zu schlissen. Es sie dass es der
# Vater und die Schwester, der sich aufgeschlossen, aber er solche Anstrenge die Schwester des Vater staerken und dank er
# sich auf den Bett auf den Bause an die Tuer und die Stuechs aus die Stamm der Schwester
# den Stumme auf dem Baue zu den Bett auf den Bett zu dem Schwester den Stock sein wenig
# auf dem Fuss aus dem Bett zurueckzug haben koennte, und wird den Kaefe in den
# Staeller auf dem Bett, die Schwester an den Tuer des
# Steilen an die Schuld der Freund der Hand und staenkte die Schwester auf
# den Beischen an den Tuer und der Verurteilten der Verueteilte schon so garzen Stell und schwarz auf
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.50260,       accuracy: 0.54354
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.47989,       accuracy: 0.54742
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.47944,       accuracy: 0.54932
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
# olennte. Er war eine Schwester mit
# einem Stock zu schliffen. Das Geld an sie sich, wie ich mir den
# Schwester zurueckgehehrte. "Der Reisende war, den Kopf nicht erklaerte. "Nur, was ich mich
# nicht mehr gerade," sagte der Offizier und dass es nicht. Es ist ein wir liesen und das Gesicht die Tuer des
# Schlesser zurueckgelehen, und die Schwere auf dem Fenster, dir ihn an die Stimme und die Schwester zu sehn.
#
# "Wie waren die Maschine geschehen, wenn er sein Augen schon in der Stadt.
#
# "Wenn ich sie nicht ein wenig genau zu haben, den ich so sehr sie sich, um die Schwester der Vater
# und schwer das Geschaefter, der er zu dem Steinen, und er war ein wenig zu sein. Wer weiss ich so gehen die Tuer, die er sei stand auf die Schwester des Verurteilten zu
# sehen, den sich auf dem Bett. Die Erkennenn der Vater schon im
# Geschaeft, und er worden wollte,, sagte er die Schwester der Strossen der Stadt aus die Staende. Den Reisenden mit
# dem Staden an sie sich auf den Bauch des Soldaten auf dem Fanz ueber si
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.46617,       accuracy: 0.55242
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.44780,       accuracy: 0.55676
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.44703,       accuracy: 0.55712
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
# alaermen in die Hoehlichkeit,
# dass die Egge seine Schwester so gehabt hatte. Die Egge sollte sich die Egge auf dem Fesser zurueck.
#
# Den Reisenden wir auf die Beine sehr zu dunden und schlaeft mit dem
# Fander und schwaerhert sich auf die Bluett den Kommandanten und die Schwester
# auf die Blutt des Schluessel und dieses Vorzummersen, die ihm aber nicht mit den Fuss ueber die Egge seine Exehution aus dem
# Familie stand der Hand und die Mutter auf die Blicke des Vaters die Erste und
# die Schwester, die ihn auch die Eltern stand die Tuer des Schreibenden zu sehen, den Schluesser aus ernem Fragen an die Beine an die
# Stimme und die Schwester die Treppe hinauf dem Bauen, die ich nicht mehr auf
# die Bluetter des Schritt selbst der Vater schliefslich die Exekution die Egge schon die
# Egge aus dem Bett. Der Reisende war schon auf den Faschin zu
# bestimmt, und dass er sich so wenig zu sehen wird das Besten
# auf die Blicke, die ihm auf dem Fenster und schliesse ihm auf dem
# Bett. Er wurde stand die Schweste
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.44466,       accuracy: 0.55965
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.43413,       accuracy: 0.56163
# Saved file: checkpoints/rnn_train_1548283113-12000000
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.43876,       accuracy: 0.56303
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
# ormen und sich
# diese Wahrung die Egge auf die Bedenken, der sich so gut
# sein wir aus dem Fenster zu bewegen. Das wirkt dich auch die
# Egge schwach die Schwester, die ich nicht aus dem Bett, die
# ich schon so sehr gerade zu sehen, dass er den Kommandanten sich auf dem Bete zu
# schlagen. Aber die Schwester so schwang er sich auch niemand zu seinen Schritten an den Schakalen
# den Schlaefen der Familie, aber er wollte sich an ihnen den
# Kopf nicht genug genug, denn er hat es so gern war,
# und warum die Schwester der Vater schliessen wir an einem Besten
# aufgeraden, und ein Schwester die Tuer seine Straffolonis, ein wenig
# zu schwaerhen und dass er sich schon die Mutter unter dem Stalle zu beweglich
# schwenken wir und das Bett zu schliessen, und dass
# das Gesicht des Schwester sollte sie mit den
# Stiefel zurueck, wenn es den Vater schliessen die
# Schwester, und die Egen des Schlaf ihm der
# Soldat, und er war schon die Tuer schliessen koennte. Aber er war sie nicht an die Tuer des
# Vater und schliesslich
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.43338,       accuracy: 0.56329
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.42678,       accuracy: 0.56447
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.43256,       accuracy: 0.56625
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
# orpen in den Stillen an den Tuer des Verurteilten, sondern solche Geschaeftsiereit war ein Gefaehlte verlangte.
# Die Eine der Haustrecht besonders auf dem Fuss in die Haende, sich an ihn niedergebrueckt, die Huefte auf den Bett aufgeschlossen hatte, so dert auch die Schwester sich auf
# die Schwester im Schluessel, um sich aufzurichtigen, die sich auf diese Weise der Freund ist zu dem Stimme aus dem
# Festen, den ihn auf dem Fussspitzen zu beweglich auf dem Bett, und da er die Bedienerin sich auf den Bett zu schlafen. Als die Schwester das Gerichtsversaenmen den
# Vater in die Geschieft an den Tuerhueter der Vater schliesslich, aber das Geschaeft des Vater schon dann bestimmt sich nicht mehr gewoehnt, dass es den Kopf im
# Gesicht aus die Schulter, die man ihn nicht mehr geradezu den Schreibtischen und den Soldat nach dem Stimmen aus. Das
# Gerichtsverfahren hatte er sich nicht vorgestellt, wenn man so schwer aus dem Bett aus die Schuesse ueber die Bedenken zu
# schweren und die Egge aber hatte sic
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.42908,       accuracy: 0.56673
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.42858,       accuracy: 0.56678
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.43041,       accuracy: 0.56594
#
# ┌───────────────────────────────────Generating random text from learned state───────────────────────────────────┐
# orfen
# haben, wie es mit gewesen hinauf. Darueber, wie er seit Zimmer ausgeruetzt hatte, dass die
# Egge auf den Fussspitzen und staerkte ein wenig hin und das Geringste an die
# Erde und das Geringste zu sein. Das geschahe wird, den Vater seines Zeichners zu sein,
# was er sich auf den Fussspitzen, die ihn aber nicht mehr
# voruebergehalten. Er wurde sich nicht mehr, um die Schwester sich zu sein, denn es wird sie sich nur die Schwester sollen wollte,
# auf dem Fenster, und die Mutter auf den
# Boden hiel zu den erstannten Anschaung der Mann zu sein. Die Erfolge der Freund ist sie zu sein. Der Vater
# schien es den Vater, der sich selbst wenn er sich nur ein wenig zu verlieren.
#
# "Nun war so gerade diese Wage zurueck. Das werde ich meine Sterne und schlug zu sein.
#
# "Wie war nur den Kopf nicht verloren war,"
#
# "Wenn ich, so gern ist es nicht sehr, er waere nicht mehr zu
# schliesslich sein." Da das kleine Gedienerin sie sich
# nicht mit dem Schluessel und diese Exekution bestimmte.
#
# "Sie haben Sie mir nich
# └───────────────────────────────────────────────End of generation───────────────────────────────────────────────┘
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.42952,       accuracy: 0.56768
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================Validating on 16304-0w_u.txt
# VALIDATION STATS:                                  loss: 1.42665,       accuracy: 0.56695
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================

# %%
author = 'checkpoints/rnn_train_1548283113-12000000'
ncnt = 0
with tf.Session() as sess:
    new_saver = tf.train.import_meta_graph('checkpoints/rnn_train_1548283113-12000000.meta')
    new_saver.restore(sess, author)
    x = txt.convert_from_alphabet(ord("L"))
    x = np.array([[x]])  # shape [BATCHSIZE, SEQLEN] with BATCHSIZE=1 and SEQLEN=1

    # initial values
    y = x
    h = np.zeros([1, INTERNALSIZE * NLAYERS], dtype=np.float32)  # [ BATCHSIZE, INTERNALSIZE * NLAYERS]
    for i in range(1000):
        yo, h = sess.run(['Yo:0', 'H:0'], feed_dict={'X:0': y, 'pkeep:0': 1., 'Hin:0': h, 'batchsize:0': 1})

        # If sampling is be done from the topn most likely characters, the generated text
        # is more credible and more "english". If topn is not set, it defaults to the full
        # distribution (ALPHASIZE)

        # Recommended: topn = 10 for intermediate checkpoints, topn=2 or 3 for fully trained checkpoints

        c = txt.sample_from_probabilities(yo, topn=2)
        y = np.array([[c]])  # shape [BATCHSIZE, SEQLEN] with BATCHSIZE=1 and SEQLEN=1
        c = chr(txt.convert_to_alphabet(c))
        print(c, end="")

        if c == '\n':
            ncnt = 0
        else:
            ncnt += 1
        if ncnt == 100:
            print("")
            ncnt = 0
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/rnn_train_1548283113-12000000
# aung und
# Schwang ein Stark. Der Reisende hatte schon die Schwester den
# Vater und den Kopf nach dem Bauch zur Tuere zu sein. Das ist diese Waerderung seiner Freunde in der
# Hungern hinter ihren Blut auf dem Bauch zu erfahren, und wie sie sehr auf dem Ballen an, das Gesicht
#  auf einem geschlafenen Kaefig an den
# Kopf, die ihn noch allerdings sein wenig zu sehen, wird der Vater und die Schwester der
# Schwester die Maedchen gestellt hatte, und die Schwester der Verurteilte seines
# Zimmer zu sein. Denn es war ein greiserer Schwester mit dem Stallen gewordenen Hand ueber den Kopf i
# m Beiten auf den Kopf, der in
# sein Zimmer ausgerade er sich auf dem Kanapee, und war das gestellt hatte,
# denn den Kopp natuerlich an einer Schritt seiner Freund hat eine Strafkelturg in
# die Schwester, den Kopf in der Haende an den Taecheln, der ihn nicht ausgestreckte Beinahlen
# des Vorzimmer zu seinem Stelb straefte das Geld des Vatirs auf dem Kopf nach einem geschaeftigen Bla
# tt auf den Kasten, der sich daran das Gelaen

# %%
author = 'checkpoints/rnn_train_1548283113-12000000'
ncnt = 0
with tf.Session() as sess:
    new_saver = tf.train.import_meta_graph('checkpoints/rnn_train_1548283113-12000000.meta')
    new_saver.restore(sess, author)
    x = txt.convert_from_alphabet(ord("L"))
    x = np.array([[x]])  # shape [BATCHSIZE, SEQLEN] with BATCHSIZE=1 and SEQLEN=1

    # initial values
    y = x
    h = np.zeros([1, INTERNALSIZE * NLAYERS], dtype=np.float32)  # [ BATCHSIZE, INTERNALSIZE * NLAYERS]
    for i in range(1000):
        yo, h = sess.run(['Yo:0', 'H:0'], feed_dict={'X:0': y, 'pkeep:0': 1., 'Hin:0': h, 'batchsize:0': 1})

        # If sampling is be done from the topn most likely characters, the generated text
        # is more credible and more "english". If topn is not set, it defaults to the full
        # distribution (ALPHASIZE)

        # Recommended: topn = 10 for intermediate checkpoints, topn=2 or 3 for fully trained checkpoints

        c = txt.sample_from_probabilities(yo, topn=10)
        y = np.array([[c]])  # shape [BATCHSIZE, SEQLEN] with BATCHSIZE=1 and SEQLEN=1
        c = chr(txt.convert_to_alphabet(c))
        print(c, end="")

        if c == '\n':
            ncnt = 0
        else:
            ncnt += 1
        if ncnt == 100:
            print("")
            ncnt = 0
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/rnn_train_1548283113-12000000
# faaessere Diess. Damars
# anfess ich hicat, sich aur diese Wagen, oben die Fuemde wurde den Hals, doch
# weit auf den Band herlicher. Einen allerminneten Schreckbis zum
# Reisenden mehr geloert, dass wenn er sich haben, die Sie unser Zeit und ein
# alter Solnungsauf den Bannen den Tieben die
# Traue zu beschreiben,
# er war aber geobsacht hat -- dass er in der Naehe war die Rad des Zeiter schleche am Alten unt ueckt
# icht gun, und, ist mit der Strassenkren und dachte sie murde aus dem Bett noch
# umzu erstiegenden Blicken etwas Dienspmuegen bedaenftig und schlafras zu den
# Schwester aufgerickt, wieder hielte er auch im Gewond auf die Troste
# sichtigstellen mit den Vater nichts zu bewendern die
# Krecher sofort, der Stilen hatten und lenne den Koff. Es dart
# nicht erfahren wurde, und en fast breite mit ihr nicht mehr doll, die
# Schwester nicht zu sehen, um die Hause der Mann, an der Hand gegen die Zigkerter durch
# die Wachtigung im Witt, noch, als sie muessen und sich den Kopf guf diesem
# Verurteilten die Klei
